# %%
import tensorflow as tf

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data", one_hot=True) #data/fashion
# Out:
# WARNING:tensorflow:From <ipython-input-2-4e25ee396bc7>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/onepanel/.conda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/onepanel/.conda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/onepanel/.conda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/onepanel/.conda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/onepanel/.conda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ## What we will be doing
#
# - Write a few helper functions (init_wgts, init_bias, conv2d, max pool, conv_layer,
# - variables, placeholders, cost, optimizers
# - Train CNN

# %%
def init_wgts(shape):
    init_random_dist = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(init_random_dist)

# %%
def init_bias(shape):
    init_bias_vals = tf.constant(0.1, shape=shape)
    return tf.Variable(init_bias_vals)

# %%
def conv2d(x, W):
    """
    x -> [batch, H, W, Channels]
    W -> [filter H, Filter W, Channel IN, Channel OUT]
    Use a stride of 1, keep padding same
    """
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

# %%
def max_pool_2by2(x):
    """
    x --> [batch, h, w, channels], a 4D Tensor
    """
    return tf.nn.max_pool(x, ksize=[1,2,2,1],
                          strides=[1,2,2,1],
                          padding='SAME')

# %%
def convolutional_layer(input_x, shape):
    W = init_wgts(shape)
    b = init_bias([shape[3]])
    return tf.nn.relu(conv2d(input_x, W) + b)

# %%
def normal_full_layer(input_layer, size):
    input_size = int(input_layer.get_shape()[1])
    W = init_wgts([input_size, size])
    b = init_bias([size])
    return tf.matmul(input_layer, W) + b

# %%
# placeholders
x = tf.placeholder(tf.float32, shape=[None, 784])
y_true = tf.placeholder(tf.float32, shape=[None, 10])

# %%
x_image = tf.reshape(x, [-1, 28, 28, 1])

# %%
# layer 1
convo_1 = convolutional_layer(x_image, shape=[5,5,1,32])
convo_1_pooling = max_pool_2by2(convo_1)
# layer 2
convo_2 = convolutional_layer(convo_1_pooling, shape=[5,5,32, 64])
convo_2_pooling = max_pool_2by2(convo_2)
# flatten it out
convo_2_flat = tf.reshape(convo_2_pooling, [-1, 7*7*64])
full_layer_one = tf.nn.relu(normal_full_layer(convo_2_flat, 1064))

# %%
#dropout 
hold_prob = tf.placeholder(tf.float32)
full_one_dropout = tf.nn.dropout(full_layer_one, keep_prob=hold_prob)

# %%
# y_pred label
y_pred = normal_full_layer(full_one_dropout, 10)

# %%
# loss
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y_true, logits=y_pred))

# %%
# optimizer 
optimizer = tf.train.AdamOptimizer(learning_rate=0.001) # tune this
train = optimizer.minimize(cross_entropy)

# %%
#tf.reset_default_graph()

# %%
# init
init = tf.global_variables_initializer()

# %%
steps = 50000

# %%
session = tf.Session()

with session as sess:
    sess.run(init)
    
    for i in range(steps):
        batch_x, batch_y = mnist.train.next_batch(500)
        # grab from the next batch
        
        sess.run(train, feed_dict={x:batch_x, y_true:batch_y, hold_prob:0.5})
        
        # print out message every 100
        
        if i%100 == 0:
            print("Currently on step{}".format(i))
            print("Accuracy is:")
            # Test the train model
            matches = tf.equal(tf.argmax(y_pred, 1), tf.argmax(y_true,1))
            acc = tf.reduce_mean(tf.cast(matches, tf.float32))
            print(sess.run(acc, feed_dict={x:mnist.test.images,
                                          y_true:mnist.test.labels,
                                          hold_prob:1.0}))
            print('\n')
# Out:
# Currently on step0
# Accuracy is:
# 0.1368
#
#
# Currently on step100
# Accuracy is:
# 0.9711
#
#
# Currently on step200
# Accuracy is:
# 0.9829
#
#
# Currently on step300
# Accuracy is:
# 0.9854
#
#
# Currently on step400
# Accuracy is:
# 0.9874
#
#
# Currently on step500
# Accuracy is:
# 0.9897
#
#
# Currently on step600
# Accuracy is:
# 0.9904
#
#
# Currently on step700
# Accuracy is:
# 0.99
#
#
# Currently on step800
# Accuracy is:
# 0.9913
#
#
# Currently on step900
# Accuracy is:
# 0.991
#
#
# Currently on step1000
# Accuracy is:
# 0.9915
#
#
# Currently on step1100
# Accuracy is:
# 0.9914
#
#
# Currently on step1200
# Accuracy is:
# 0.9922
#
#
# Currently on step1300
# Accuracy is:
# 0.9917
#
#
# Currently on step1400
# Accuracy is:
# 0.9913
#
#
# Currently on step1500
# Accuracy is:
# 0.9913
#
#
# Currently on step1600
# Accuracy is:
# 0.9928
#
#
# Currently on step1700
# Accuracy is:
# 0.9919
#
#
# Currently on step1800
# Accuracy is:
# 0.9919
#
#
# Currently on step1900
# Accuracy is:
# 0.9918
#
#
# Currently on step2000
# Accuracy is:
# 0.9922
#
#
# Currently on step2100
# Accuracy is:
# 0.992
#
#
# Currently on step2200
# Accuracy is:
# 0.9926
#
#
# Currently on step2300
# Accuracy is:
# 0.9912
#
#
# Currently on step2400
# Accuracy is:
# 0.9922
#
#
# Currently on step2500
# Accuracy is:
# 0.9925
#
#
# Currently on step2600
# Accuracy is:
# 0.9923
#
#
# Currently on step2700
# Accuracy is:
# 0.9924
#
#
# Currently on step2800
# Accuracy is:
# 0.9909
#
#
# Currently on step2900
# Accuracy is:
# 0.9925
#
#
# Currently on step3000
# Accuracy is:
# 0.9927
#
#
# Currently on step3100
# Accuracy is:
# 0.9926
#
#
# Currently on step3200
# Accuracy is:
# 0.9923
#
#
# Currently on step3300
# Accuracy is:
# 0.9917
#
#
# Currently on step3400
# Accuracy is:
# 0.9919
#
#
# Currently on step3500
# Accuracy is:
# 0.9929
#
#
# Currently on step3600
# Accuracy is:
# 0.9925
#
#
# Currently on step3700
# Accuracy is:
# 0.9916
#
#
# Currently on step3800
# Accuracy is:
# 0.9924
#
#
# Currently on step3900
# Accuracy is:
# 0.9913
#
#
# Currently on step4000
# Accuracy is:
# 0.992
#
#
# Currently on step4100
# Accuracy is:
# 0.9917
#
#
# Currently on step4200
# Accuracy is:
# 0.9916
#
#
# Currently on step4300
# Accuracy is:
# 0.9925
#
#
# Currently on step4400
# Accuracy is:
# 0.9922
#
#
# Currently on step4500
# Accuracy is:
# 0.9922
#
#
# Currently on step4600
# Accuracy is:
# 0.992
#
#
# Currently on step4700
# Accuracy is:
# 0.9928
#
#
# Currently on step4800
# Accuracy is:
# 0.9916
#
#
# Currently on step4900
# Accuracy is:
# 0.993
#
#
# Currently on step5000
# Accuracy is:
# 0.9932
#
#
# Currently on step5100
# Accuracy is:
# 0.9918
#
#
# Currently on step5200
# Accuracy is:
# 0.992
#
#
# Currently on step5300
# Accuracy is:
# 0.9924
#
#
# Currently on step5400
# Accuracy is:
# 0.992
#
#
# Currently on step5500
# Accuracy is:
# 0.9919
#
#
# Currently on step5600
# Accuracy is:
# 0.9932
#
#
# Currently on step5700
# Accuracy is:
# 0.9924
#
#
# Currently on step5800
# Accuracy is:
# 0.9923
#
#
# Currently on step5900
# Accuracy is:
# 0.9927
#
#
# Currently on step6000
# Accuracy is:
# 0.9926
#
#
# Currently on step6100
# Accuracy is:
# 0.9921
#
#
# Currently on step6200
# Accuracy is:
# 0.9926
#
#
# Currently on step6300
# Accuracy is:
# 0.9922
#
#
# Currently on step6400
# Accuracy is:
# 0.9927
#
#
# Currently on step6500
# Accuracy is:
# 0.9931
#
#
# Currently on step6600
# Accuracy is:
# 0.9928
#
#
# Currently on step6700
# Accuracy is:
# 0.9925
#
#
# Currently on step6800
# Accuracy is:
# 0.9921
#
#
# Currently on step6900
# Accuracy is:
# 0.9913
#
#
# Currently on step7000
# Accuracy is:
# 0.9922
#
#
# Currently on step7100
# Accuracy is:
# 0.9909
#
#
# Currently on step7200
# Accuracy is:
# 0.9922
#
#
# Currently on step7300
# Accuracy is:
# 0.9932
#
#
# Currently on step7400
# Accuracy is:
# 0.9928
#
#
# Currently on step7500
# Accuracy is:
# 0.9924
#
#
# Currently on step7600
# Accuracy is:
# 0.9925
#
#
# Currently on step7700
# Accuracy is:
# 0.9933
#
#
# Currently on step7800
# Accuracy is:
# 0.9921
#
#
# Currently on step7900
# Accuracy is:
# 0.9922
#
#
# Currently on step8000
# Accuracy is:
# 0.9927
#
#
# Currently on step8100
# Accuracy is:
# 0.9926
#
#
# Currently on step8200
# Accuracy is:
# 0.9926
#
#
# Currently on step8300
# Accuracy is:
# 0.9935
#
#
# Currently on step8400
# Accuracy is:
# 0.9925
#
#
# Currently on step8500
# Accuracy is:
# 0.9926
#
#
# Currently on step8600
# Accuracy is:
# 0.9921
#
#
# Currently on step8700
# Accuracy is:
# 0.991
#
#
# Currently on step8800
# Accuracy is:
# 0.9919
#
#
# Currently on step8900
# Accuracy is:
# 0.9924
#
#
# Currently on step9000
# Accuracy is:
# 0.9929
#
#
# Currently on step9100
# Accuracy is:
# 0.9937
#
#
# Currently on step9200
# Accuracy is:
# 0.9929
#
#
# Currently on step9300
# Accuracy is:
# 0.9931
#
#
# Currently on step9400
# Accuracy is:
# 0.9929
#
#
# Currently on step9500
# Accuracy is:
# 0.9913
#
#
# Currently on step9600
# Accuracy is:
# 0.9924
#
#
# Currently on step9700
# Accuracy is:
# 0.9929
#
#
# Currently on step9800
# Accuracy is:
# 0.9928
#
#
# Currently on step9900
# Accuracy is:
# 0.993
#
#
# Currently on step10000
# Accuracy is:
# 0.9939
#
#
# Currently on step10100
# Accuracy is:
# 0.9931
#
#
# Currently on step10200
# Accuracy is:
# 0.9927
#
#
# Currently on step10300
# Accuracy is:
# 0.9937
#
#
# Currently on step10400
# Accuracy is:
# 0.9933
#
#
# Currently on step10500
# Accuracy is:
# 0.9934
#
#
# Currently on step10600
# Accuracy is:
# 0.9931
#
#
# Currently on step10700
# Accuracy is:
# 0.9917
#
#
# Currently on step10800
# Accuracy is:
# 0.9919
#
#
# Currently on step10900
# Accuracy is:
# 0.9914
#
#
# Currently on step11000
# Accuracy is:
# 0.992
#
#
# Currently on step11100
# Accuracy is:
# 0.994
#
#
# Currently on step11200
# Accuracy is:
# 0.9934
#
#
# Currently on step11300
# Accuracy is:
# 0.993
#
#
# Currently on step11400
# Accuracy is:
# 0.993
#
#
# Currently on step11500
# Accuracy is:
# 0.9926
#
#
# Currently on step11600
# Accuracy is:
# 0.9923
#
#
# Currently on step11700
# Accuracy is:
# 0.994
#
#
# Currently on step11800
# Accuracy is:
# 0.9933
#
#
# Currently on step11900
# Accuracy is:
# 0.9926
#
#
# Currently on step12000
# Accuracy is:
# 0.9919
#
#
# Currently on step12100
# Accuracy is:
# 0.9927
#
#
# Currently on step12200
# Accuracy is:
# 0.9927
#
#
# Currently on step12300
# Accuracy is:
# 0.9931
#
#
# Currently on step12400
# Accuracy is:
# 0.993
#
#
# Currently on step12500
# Accuracy is:
# 0.992
#
#
# Currently on step12600
# Accuracy is:
# 0.9925
#
#
# Currently on step12700
# Accuracy is:
# 0.9926
#
#
# Currently on step12800
# Accuracy is:
# 0.9933
#
#
# Currently on step12900
# Accuracy is:
# 0.9932
#
#
# Currently on step13000
# Accuracy is:
# 0.9933
#
#
# Currently on step13100
# Accuracy is:
# 0.9936
#
#
# Currently on step13200
# Accuracy is:
# 0.9926
#
#
# Currently on step13300
# Accuracy is:
# 0.9925
#
#
# Currently on step13400
# Accuracy is:
# 0.9929
#
#
# Currently on step13500
# Accuracy is:
# 0.9921
#
#
# Currently on step13600
# Accuracy is:
# 0.9926
#
#
# Currently on step13700
# Accuracy is:
# 0.9919
#
#
# Currently on step13800
# Accuracy is:
# 0.9918
#
#
# Currently on step13900
# Accuracy is:
# 0.9929
#
#
# Currently on step14000
# Accuracy is:
# 0.993
#
#
# Currently on step14100
# Accuracy is:
# 0.9933
#
#
# Currently on step14200
# Accuracy is:
# 0.9927
#
#
# Currently on step14300
# Accuracy is:
# 0.9923
#
#
# Currently on step14400
# Accuracy is:
# 0.9922
#
#
# Currently on step14500
# Accuracy is:
# 0.9932
#
#
# Currently on step14600
# Accuracy is:
# 0.9938
#
#
# Currently on step14700
# Accuracy is:
# 0.9928
#
#
# Currently on step14800
# Accuracy is:
# 0.9931
#
#
# Currently on step14900
# Accuracy is:
# 0.994
#
#
# Currently on step15000
# Accuracy is:
# 0.9932
#
#
# Currently on step15100
# Accuracy is:
# 0.9929
#
#
# Currently on step15200
# Accuracy is:
# 0.9921
#
#
# Currently on step15300
# Accuracy is:
# 0.9932
#
#
# Currently on step15400
# Accuracy is:
# 0.9931
#
#
# Currently on step15500
# Accuracy is:
# 0.9925
#
#
# Currently on step15600
# Accuracy is:
# 0.9929
#
#
# Currently on step15700
# Accuracy is:
# 0.9927
#
#
# Currently on step15800
# Accuracy is:
# 0.9926
#
#
# Currently on step15900
# Accuracy is:
# 0.9936
#
#
# Currently on step16000
# Accuracy is:
# 0.9928
#
#
# Currently on step16100
# Accuracy is:
# 0.9937
#
#
# Currently on step16200
# Accuracy is:
# 0.9933
#
#
# Currently on step16300
# Accuracy is:
# 0.9935
#
#
# Currently on step16400
# Accuracy is:
# 0.9932
#
#
# Currently on step16500
# Accuracy is:
# 0.9923
#
#
# Currently on step16600
# Accuracy is:
# 0.9934
#
#
# Currently on step16700
# Accuracy is:
# 0.9927
#
#
# Currently on step16800
# Accuracy is:
# 0.9921
#
#
# Currently on step16900
# Accuracy is:
# 0.9925
#
#
# Currently on step17000
# Accuracy is:
# 0.9935
#
#
# Currently on step17100
# Accuracy is:
# 0.994
#
#
# Currently on step17200
# Accuracy is:
# 0.9938
#
#
# Currently on step17300
# Accuracy is:
# 0.9933
#
#
# Currently on step17400
# Accuracy is:
# 0.9936
#
#
# Currently on step17500
# Accuracy is:
# 0.9937
#
#
# Currently on step17600
# Accuracy is:
# 0.9929
#
#
# Currently on step17700
# Accuracy is:
# 0.9936
#
#
# Currently on step17800
# Accuracy is:
# 0.994
#
#
# Currently on step17900
# Accuracy is:
# 0.9937
#
#
# Currently on step18000
# Accuracy is:
# 0.9929
#
#
# Currently on step18100
# Accuracy is:
# 0.9931
#
#
# Currently on step18200
# Accuracy is:
# 0.9937
#
#
# Currently on step18300
# Accuracy is:
# 0.9941
#
#
# Currently on step18400
# Accuracy is:
# 0.9939
#
#
# Currently on step18500
# Accuracy is:
# 0.9942
#
#
# Currently on step18600
# Accuracy is:
# 0.9935
#
#
# Currently on step18700
# Accuracy is:
# 0.9928
#
#
# Currently on step18800
# Accuracy is:
# 0.993
#
#
# Currently on step18900
# Accuracy is:
# 0.9933
#
#
# Currently on step19000
# Accuracy is:
# 0.9937
#
#
# Currently on step19100
# Accuracy is:
# 0.9933
#
#
# Currently on step19200
# Accuracy is:
# 0.9939
#
#
# Currently on step19300
# Accuracy is:
# 0.994
#
#
# Currently on step19400
# Accuracy is:
# 0.9933
#
#
# Currently on step19500
# Accuracy is:
# 0.9933
#
#
# Currently on step19600
# Accuracy is:
# 0.9932
#
#
# Currently on step19700
# Accuracy is:
# 0.9925
#
#
# Currently on step19800
# Accuracy is:
# 0.9922
#
#
# Currently on step19900
# Accuracy is:
# 0.9933
#
#
# Currently on step20000
# Accuracy is:
# 0.9932
#
#
# Currently on step20100
# Accuracy is:
# 0.9939
#
#
# Currently on step20200
# Accuracy is:
# 0.993
#
#
# Currently on step20300
# Accuracy is:
# 0.9932
#
#
# Currently on step20400
# Accuracy is:
# 0.9933
#
#
# Currently on step20500
# Accuracy is:
# 0.9934
#
#
# Currently on step20600
# Accuracy is:
# 0.9931
#
#
# Currently on step20700
# Accuracy is:
# 0.9937
#
#
# Currently on step20800
# Accuracy is:
# 0.9927
#
#
# Currently on step20900
# Accuracy is:
# 0.992
#
#
# Currently on step21000
# Accuracy is:
# 0.9939
#
#
# Currently on step21100
# Accuracy is:
# 0.993
#
#
# Currently on step21200
# Accuracy is:
# 0.9931
#
#
# Currently on step21300
# Accuracy is:
# 0.9934
#
#
# Currently on step21400
# Accuracy is:
# 0.9939
#
#
# Currently on step21500
# Accuracy is:
# 0.9932
#
#
# Currently on step21600
# Accuracy is:
# 0.9938
#
#
# Currently on step21700
# Accuracy is:
# 0.9928
#
#
# Currently on step21800
# Accuracy is:
# 0.9935
#
#
# Currently on step21900
# Accuracy is:
# 0.9933
#
#
# Currently on step22000
# Accuracy is:
# 0.9937
#
#
# Currently on step22100
# Accuracy is:
# 0.9934
#
#
# Currently on step22200
# Accuracy is:
# 0.9938
#
#
# Currently on step22300
# Accuracy is:
# 0.9937
#
#
# Currently on step22400
# Accuracy is:
# 0.9941
#
#
# Currently on step22500
# Accuracy is:
# 0.9933
#
#
# Currently on step22600
# Accuracy is:
# 0.9937
#
#
# Currently on step22700
# Accuracy is:
# 0.9933
#
#
# Currently on step22800
# Accuracy is:
# 0.9937
#
#
# Currently on step22900
# Accuracy is:
# 0.9928
#
#
# Currently on step23000
# Accuracy is:
# 0.9935
#
#
# Currently on step23100
# Accuracy is:
# 0.9933
#
#
# Currently on step23200
# Accuracy is:
# 0.9931
#
#
# Currently on step23300
# Accuracy is:
# 0.9923
#
#
# Currently on step23400
# Accuracy is:
# 0.993
#
#
# Currently on step23500
# Accuracy is:
# 0.9932
#
#
# Currently on step23600
# Accuracy is:
# 0.9932
#
#
# Currently on step23700
# Accuracy is:
# 0.9931
#
#
# Currently on step23800
# Accuracy is:
# 0.9923
#
#
# Currently on step23900
# Accuracy is:
# 0.9926
#
#
# Currently on step24000
# Accuracy is:
# 0.9935
#
#
# Currently on step24100
# Accuracy is:
# 0.9931
#
#
# Currently on step24200
# Accuracy is:
# 0.9929
#
#
# Currently on step24300
# Accuracy is:
# 0.9932
#
#
# Currently on step24400
# Accuracy is:
# 0.9923
#
#
# Currently on step24500
# Accuracy is:
# 0.9933
#
#
# Currently on step24600
# Accuracy is:
# 0.9938
#
#
# Currently on step24700
# Accuracy is:
# 0.9915
#
#
# Currently on step24800
# Accuracy is:
# 0.9934
#
#
# Currently on step24900
# Accuracy is:
# 0.993
#
#
# Currently on step25000
# Accuracy is:
# 0.9929
#
#
# Currently on step25100
# Accuracy is:
# 0.9936
#
#
# Currently on step25200
# Accuracy is:
# 0.9938
#
#
# Currently on step25300
# Accuracy is:
# 0.9938
#
#
# Currently on step25400
# Accuracy is:
# 0.9923
#
#
# Currently on step25500
# Accuracy is:
# 0.9937
#
#
# Currently on step25600
# Accuracy is:
# 0.9941
#
#
# Currently on step25700
# Accuracy is:
# 0.9932
#
#
# Currently on step25800
# Accuracy is:
# 0.993
#
#
# Currently on step25900
# Accuracy is:
# 0.9939
#
#
# Currently on step26000
# Accuracy is:
# 0.9931
#
#
# Currently on step26100
# Accuracy is:
# 0.9931
#
#
# Currently on step26200
# Accuracy is:
# 0.993
#
#
# Currently on step26300
# Accuracy is:
# 0.9939
#
#
# Currently on step26400
# Accuracy is:
# 0.9923
#
#
# Currently on step26500
# Accuracy is:
# 0.9926
#
#
# Currently on step26600
# Accuracy is:
# 0.9935
#
#
# Currently on step26700
# Accuracy is:
# 0.9935
#
#
# Currently on step26800
# Accuracy is:
# 0.9937
#
#
# Currently on step26900
# Accuracy is:
# 0.9933
#
#
# Currently on step27000
# Accuracy is:
# 0.993
#
#
# Currently on step27100
# Accuracy is:
# 0.9922
#
#
# Currently on step27200
# Accuracy is:
# 0.9923
#
#
# Currently on step27300
# Accuracy is:
# 0.9924
#
#
# Currently on step27400
# Accuracy is:
# 0.9928
#
#
# Currently on step27500
# Accuracy is:
# 0.9933
#
#
# Currently on step27600
# Accuracy is:
# 0.9926
#
#
# Currently on step27700
# Accuracy is:
# 0.9935
#
#
# Currently on step27800
# Accuracy is:
# 0.9942
#
#
# Currently on step27900
# Accuracy is:
# 0.9932
#
#
# Currently on step28000
# Accuracy is:
# 0.9935
#
#
# Currently on step28100
# Accuracy is:
# 0.9934
#
#
# Currently on step28200
# Accuracy is:
# 0.9934
#
#
# Currently on step28300
# Accuracy is:
# 0.9937
#
#
# Currently on step28400
# Accuracy is:
# 0.9938
#
#
# Currently on step28500
# Accuracy is:
# 0.9928
#
#
# Currently on step28600
# Accuracy is:
# 0.9928
#
#
# Currently on step28700
# Accuracy is:
# 0.9931
#
#
# Currently on step28800
# Accuracy is:
# 0.9932
#
#
# Currently on step28900
# Accuracy is:
# 0.9935
#
#
# Currently on step29000
# Accuracy is:
# 0.994
#
#
# Currently on step29100
# Accuracy is:
# 0.9927
#
#
# Currently on step29200
# Accuracy is:
# 0.9937
#
#
# Currently on step29300
# Accuracy is:
# 0.9944
#
#
# Currently on step29400
# Accuracy is:
# 0.9925
#
#
# Currently on step29500
# Accuracy is:
# 0.9932
#
#
# Currently on step29600
# Accuracy is:
# 0.9933
#
#
# Currently on step29700
# Accuracy is:
# 0.9926
#
#
# Currently on step29800
# Accuracy is:
# 0.9933
#
#
# Currently on step29900
# Accuracy is:
# 0.9934
#
#
# Currently on step30000
# Accuracy is:
# 0.9942
#
#
# Currently on step30100
# Accuracy is:
# 0.9938
#
#
# Currently on step30200
# Accuracy is:
# 0.9938
#
#
# Currently on step30300
# Accuracy is:
# 0.9928
#
#
# Currently on step30400
# Accuracy is:
# 0.994
#
#
# Currently on step30500
# Accuracy is:
# 0.9933
#
#
# Currently on step30600
# Accuracy is:
# 0.9935
#
#
# Currently on step30700
# Accuracy is:
# 0.9937
#
#
# Currently on step30800
# Accuracy is:
# 0.9928
#
#
# Currently on step30900
# Accuracy is:
# 0.9937
#
#
# Currently on step31000
# Accuracy is:
# 0.994
#
#
# Currently on step31100
# Accuracy is:
# 0.9937
#
#
# Currently on step31200
# Accuracy is:
# 0.9938
#
#
# Currently on step31300
# Accuracy is:
# 0.9935
#
#
# Currently on step31400
# Accuracy is:
# 0.9941
#
#
# Currently on step31500
# Accuracy is:
# 0.9939
#
#
# Currently on step31600
# Accuracy is:
# 0.9935
#
#
# Currently on step31700
# Accuracy is:
# 0.9931
#
#
# Currently on step31800
# Accuracy is:
# 0.9948
#
#
# Currently on step31900
# Accuracy is:
# 0.9939
#
#
# Currently on step32000
# Accuracy is:
# 0.9942
#
#
# Currently on step32100
# Accuracy is:
# 0.9934
#
#
# Currently on step32200
# Accuracy is:
# 0.9925
#
#
# Currently on step32300
# Accuracy is:
# 0.9928
#
#
# Currently on step32400
# Accuracy is:
# 0.9927
#
#
# Currently on step32500
# Accuracy is:
# 0.9926
#
#
# Currently on step32600
# Accuracy is:
# 0.9932
#
#
# Currently on step32700
# Accuracy is:
# 0.9936
#
#
# Currently on step32800
# Accuracy is:
# 0.9936
#
#
# Currently on step32900
# Accuracy is:
# 0.993
#
#
# Currently on step33000
# Accuracy is:
# 0.9941
#
#
# Currently on step33100
# Accuracy is:
# 0.9936
#
#
# Currently on step33200
# Accuracy is:
# 0.9932
#
#
# Currently on step33300
# Accuracy is:
# 0.9937
#
#
# Currently on step33400
# Accuracy is:
# 0.9934
#
#
# Currently on step33500
# Accuracy is:
# 0.9932
#
#
# Currently on step33600
# Accuracy is:
# 0.994
#
#
# Currently on step33700
# Accuracy is:
# 0.9928
#
#
# Currently on step33800
# Accuracy is:
# 0.9937
#
#
# Currently on step33900
# Accuracy is:
# 0.9936
#
#
# Currently on step34000
# Accuracy is:
# 0.9929
#
#
# Currently on step34100
# Accuracy is:
# 0.9936
#
#
# Currently on step34200
# Accuracy is:
# 0.9937
#
#
# Currently on step34300
# Accuracy is:
# 0.993
#
#
# Currently on step34400
# Accuracy is:
# 0.9933
#
#
# Currently on step34500
# Accuracy is:
# 0.9926
#
#
# Currently on step34600
# Accuracy is:
# 0.9927
#
#
# Currently on step34700
# Accuracy is:
# 0.993
#
#
# Currently on step34800
# Accuracy is:
# 0.9933
#
#
# Currently on step34900
# Accuracy is:
# 0.993
#
#
# Currently on step35000
# Accuracy is:
# 0.9932
#
#
# Currently on step35100
# Accuracy is:
# 0.9919
#
#
# Currently on step35200
# Accuracy is:
# 0.9925
#
#
# Currently on step35300
# Accuracy is:
# 0.9932
#
#
# Currently on step35400
# Accuracy is:
# 0.9932
#
#
# Currently on step35500
# Accuracy is:
# 0.9935
#
#
# Currently on step35600
# Accuracy is:
# 0.9939
#
#
# Currently on step35700
# Accuracy is:
# 0.9938
#
#
# Currently on step35800
# Accuracy is:
# 0.9937
#
#
# Currently on step35900
# Accuracy is:
# 0.9927
#
#
# Currently on step36000
# Accuracy is:
# 0.9942
#
#
# Currently on step36100
# Accuracy is:
# 0.9943
#
#
# Currently on step36200
# Accuracy is:
# 0.9933
#
#
# Currently on step36300
# Accuracy is:
# 0.9937
#
#
# Currently on step36400
# Accuracy is:
# 0.9932
#
#
# Currently on step36500
# Accuracy is:
# 0.9938
#
#
# Currently on step36600
# Accuracy is:
# 0.9928
#
#
# Currently on step36700
# Accuracy is:
# 0.9937
#
#
# Currently on step36800
# Accuracy is:
# 0.9935
#
#
# Currently on step36900
# Accuracy is:
# 0.9926
#
#
# Currently on step37000
# Accuracy is:
# 0.9917
#
#
# Currently on step37100
# Accuracy is:
# 0.9921
#
#
# Currently on step37200
# Accuracy is:
# 0.9941
#
#
# Currently on step37300
# Accuracy is:
# 0.9935
#
#
# Currently on step37400
# Accuracy is:
# 0.9931
#
#
# Currently on step37500
# Accuracy is:
# 0.9926
#
#
# Currently on step37600
# Accuracy is:
# 0.9937
#
#
# Currently on step37700
# Accuracy is:
# 0.9929
#
#
# Currently on step37800
# Accuracy is:
# 0.9929
#
#
# Currently on step37900
# Accuracy is:
# 0.9941
#
#
# Currently on step38000
# Accuracy is:
# 0.9941
#
#
# Currently on step38100
# Accuracy is:
# 0.9931
#
#
# Currently on step38200
# Accuracy is:
# 0.994
#
#
# Currently on step38300
# Accuracy is:
# 0.994
#
#
# Currently on step38400
# Accuracy is:
# 0.9938
#
#
# Currently on step38500
# Accuracy is:
# 0.9926
#
#
# Currently on step38600
# Accuracy is:
# 0.9935
#
#
# Currently on step38700
# Accuracy is:
# 0.9943
#
#
# Currently on step38800
# Accuracy is:
# 0.9944
#
#
# Currently on step38900
# Accuracy is:
# 0.9938
#
#
# Currently on step39000
# Accuracy is:
# 0.9938
#
#
# Currently on step39100
# Accuracy is:
# 0.9933
#
#
# Currently on step39200
# Accuracy is:
# 0.9932
#
#
# Currently on step39300
# Accuracy is:
# 0.9935
#
#
# Currently on step39400
# Accuracy is:
# 0.9944
#
#
# Currently on step39500
# Accuracy is:
# 0.9939
#
#
# Currently on step39600
# Accuracy is:
# 0.9933
#
#
# Currently on step39700
# Accuracy is:
# 0.9939
#
#
# Currently on step39800
# Accuracy is:
# 0.9931
#
#
# Currently on step39900
# Accuracy is:
# 0.9922
#
#
# Currently on step40000
# Accuracy is:
# 0.9929
#
#
# Currently on step40100
# Accuracy is:
# 0.9935
#
#
# Currently on step40200
# Accuracy is:
# 0.9942
#
#
# Currently on step40300
# Accuracy is:
# 0.995
#
#
# Currently on step40400
# Accuracy is:
# 0.9948
#
#
# Currently on step40500
# Accuracy is:
# 0.9943
#
#
# Currently on step40600
# Accuracy is:
# 0.9938
#
#
# Currently on step40700
# Accuracy is:
# 0.9947
#
#
# Currently on step40800
# Accuracy is:
# 0.9942
#
#
# Currently on step40900
# Accuracy is:
# 0.9935
#
#
# Currently on step41000
# Accuracy is:
# 0.9941
#
#
# Currently on step41100
# Accuracy is:
# 0.994
#
#
# Currently on step41200
# Accuracy is:
# 0.993
#
#
# Currently on step41300
# Accuracy is:
# 0.9938
#
#
# Currently on step41400
# Accuracy is:
# 0.9934
#
#
# Currently on step41500
# Accuracy is:
# 0.994
#
#
# Currently on step41600
# Accuracy is:
# 0.9938
#
#
# Currently on step41700
# Accuracy is:
# 0.9935
#
#
# Currently on step41800
# Accuracy is:
# 0.9945
#
#
# Currently on step41900
# Accuracy is:
# 0.9939
#
#
# Currently on step42000
# Accuracy is:
# 0.9945
#
#
# Currently on step42100
# Accuracy is:
# 0.9939
#
#
# Currently on step42200
# Accuracy is:
# 0.9939
#
#
# Currently on step42300
# Accuracy is:
# 0.9932
#
#
# Currently on step42400
# Accuracy is:
# 0.9939
#
#
# Currently on step42500
# Accuracy is:
# 0.9934
#
#
# Currently on step42600
# Accuracy is:
# 0.9938
#
#
# Currently on step42700
# Accuracy is:
# 0.9939
#
#
# Currently on step42800
# Accuracy is:
# 0.9942
#
#
# Currently on step42900
# Accuracy is:
# 0.994
#
#
# Currently on step43000
# Accuracy is:
# 0.9942
#
#
# Currently on step43100
# Accuracy is:
# 0.993
#
#
# Currently on step43200
# Accuracy is:
# 0.9938
#
#
# Currently on step43300
# Accuracy is:
# 0.9943
#
#
# Currently on step43400
# Accuracy is:
# 0.9938
#
#
# Currently on step43500
# Accuracy is:
# 0.9939
#
#
# Currently on step43600
# Accuracy is:
# 0.9934
#
#
# Currently on step43700
# Accuracy is:
# 0.9944
#
#
# Currently on step43800
# Accuracy is:
# 0.9943
#
#
# Currently on step43900
# Accuracy is:
# 0.9943
#
#
# Currently on step44000
# Accuracy is:
# 0.9928
#
#
# Currently on step44100
# Accuracy is:
# 0.9934
#
#
# Currently on step44200
# Accuracy is:
# 0.993
#
#
# Currently on step44300
# Accuracy is:
# 0.9927
#
#
# Currently on step44400
# Accuracy is:
# 0.9941
#
#
# Currently on step44500
# Accuracy is:
# 0.9939
#
#
# Currently on step44600
# Accuracy is:
# 0.9938
#
#
# Currently on step44700
# Accuracy is:
# 0.9937
#
#
# Currently on step44800
# Accuracy is:
# 0.9941
#
#
# Currently on step44900
# Accuracy is:
# 0.9937
#
#
# Currently on step45000
# Accuracy is:
# 0.994
#
#
# Currently on step45100
# Accuracy is:
# 0.9939
#
#
# Currently on step45200
# Accuracy is:
# 0.994
#
#
# Currently on step45300
# Accuracy is:
# 0.9937
#
#
# Currently on step45400
# Accuracy is:
# 0.9937
#
#
# Currently on step45500
# Accuracy is:
# 0.994
#
#
# Currently on step45600
# Accuracy is:
# 0.9941
#
#
# Currently on step45700
# Accuracy is:
# 0.9929
#
#
# Currently on step45800
# Accuracy is:
# 0.9933
#
#
# Currently on step45900
# Accuracy is:
# 0.9939
#
#
# Currently on step46000
# Accuracy is:
# 0.9939
#
#
# Currently on step46100
# Accuracy is:
# 0.9936
#
#
# Currently on step46200
# Accuracy is:
# 0.993
#
#
# Currently on step46300
# Accuracy is:
# 0.9941
#
#
# Currently on step46400
# Accuracy is:
# 0.9937
#
#
# Currently on step46500
# Accuracy is:
# 0.9927
#
#
# Currently on step46600
# Accuracy is:
# 0.9927
#
#
# Currently on step46700
# Accuracy is:
# 0.9933
#
#
# Currently on step46800
# Accuracy is:
# 0.9935
#
#
# Currently on step46900
# Accuracy is:
# 0.9928
#
#
# Currently on step47000
# Accuracy is:
# 0.9939
#
#
# Currently on step47100
# Accuracy is:
# 0.9928
#
#
# Currently on step47200
# Accuracy is:
# 0.9937
#
#
# Currently on step47300
# Accuracy is:
# 0.9935
#
#
# Currently on step47400
# Accuracy is:
# 0.9939
#
#
# Currently on step47500
# Accuracy is:
# 0.9943
#
#
# Currently on step47600
# Accuracy is:
# 0.9945
#
#
# Currently on step47700
# Accuracy is:
# 0.9941
#
#
# Currently on step47800
# Accuracy is:
# 0.9935
#
#
# Currently on step47900
# Accuracy is:
# 0.9937
#
#
# Currently on step48000
# Accuracy is:
# 0.9939
#
#
# Currently on step48100
# Accuracy is:
# 0.9935
#
#
# Currently on step48200
# Accuracy is:
# 0.9939
#
#
# Currently on step48300
# Accuracy is:
# 0.9933
#
#
# Currently on step48400
# Accuracy is:
# 0.9935
#
#
# Currently on step48500
# Accuracy is:
# 0.9943
#
#
# Currently on step48600
# Accuracy is:
# 0.9922
#
#
# Currently on step48700
# Accuracy is:
# 0.9935
#
#
# Currently on step48800
# Accuracy is:
# 0.9942
#
#
# Currently on step48900
# Accuracy is:
# 0.9951
#
#
# Currently on step49000
# Accuracy is:
# 0.9932
#
#
# Currently on step49100
# Accuracy is:
# 0.9945
#
#
# Currently on step49200
# Accuracy is:
# 0.994
#
#
# Currently on step49300
# Accuracy is:
# 0.9935
#
#
# Currently on step49400
# Accuracy is:
# 0.9932
#
#
# Currently on step49500
# Accuracy is:
# 0.9928
#
#
# Currently on step49600
# Accuracy is:
# 0.9931
#
#
# Currently on step49700
# Accuracy is:
# 0.9937
#
#
# Currently on step49800
# Accuracy is:
# 0.9935
#
#
# Currently on step49900
# Accuracy is:
# 0.9931
